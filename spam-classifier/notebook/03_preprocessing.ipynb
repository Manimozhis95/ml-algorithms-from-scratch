# %%
import sys
import os

sys.path.append(os.path.abspath(".."))
from src.preprocess import process_pipeline

df = process_pipeline("../data/processed/cleaned_spam.csv")
df.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
from src.preprocess import preprocess_text
df['transformed_message']=df['message'].apply(preprocess_text)
df.head()
# Out:
#   label                                            message  \
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...
#
#                                  transformed_message
# 0  go jurong point crazi avail bugi n great world...
# 1                              ok lar joke wif u oni
# 2  free entri wkli comp win fa cup final tkt st m...
# 3                u dun say earli hor u c alreadi say
# 4          nah dont think goe usf live around though

# %%
df['label'] = df['label'].map({'ham': 0, 'spam': 1})

# %%
df.to_csv('../data/processed/transformed_spam.csv',index=False)
