# %%
import sys
import os

sys.path.append(os.path.abspath(".."))
from src.preprocess import process_pipeline

df = process_pipeline("../data/raw/spam.csv")
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
print (df.shape)
print (df.head())
print(df.columns)
print(df.info())
# Out:
# (5572, 5)
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN
# Index(['v1', 'v2', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], dtype='str')
# <class 'pandas.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   str
#  1   v2          5572 non-null   str
#  2   Unnamed: 2  50 non-null     str
# ...

# %%
df.isnull().sum()
df.columns
# Out:
# Index(['v1', 'v2', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], dtype='str')

# %%
df['v1'].value_counts()
#understanding label distribution 
import seaborn as sns 
sns.countplot(x=df['v1'])
# Out:
# <Axes: xlabel='v1', ylabel='count'>

# %%
import seaborn as sns
df['message_length'] = df['v2'].apply(len)
sns.histplot(df['message_length'])
# Out:
# <Axes: xlabel='message_length', ylabel='Count'>

# %% [markdown]
# The dataset is imbalanced, with significantly more ham messages than spam. This can affect model performance, so I plan to use appropriate evaluation metrics like precision, recall, and F1-score instead of relying only on accuracy
